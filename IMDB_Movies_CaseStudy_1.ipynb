# %% [markdown]
# <a href="https://colab.research.google.com/github/GiriSrinivasan/IMDB-Movies-Case-Study-1/blob/main/IMDB_Movies_CaseStudy_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Filtering out the warnings

import warnings

warnings.filterwarnings('ignore')

# %%
# importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading the CSV file
movies = pd.read_csv("C:\Data Science\Case Studies\Movie Reviews\Movie+Assignment+Data.csv")
movies.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %%
# checking the number of rows and columns
movies.shape
# Out:
# (100, 62)

# %%
# check the cloumn wise info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
# summary of the movies dataframe
movies.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %%
# Divide the 'gross' and 'budget' columns by 1000000 to convert '$' to 'million $'
movies["Gross"] = movies["Gross"]/1000000
movies["budget"]= movies["budget"]/1000000
movies.head()
# Out:
#                                          Title  title_year         budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015  2.450000e-108
# 11                                The Avengers        2012  2.200000e-108
# 47                                    Deadpool        2016  5.800000e-109
# 32             The Hunger Games: Catching Fire        2013  1.300000e-108
# 12                                 Toy Story 3        2010  2.000000e-108
#
#             Gross       actor_1_name       actor_2_name  \
# 97  9.366622e-108        Doug Walker         Rob Walker
# 11  6.232795e-108    Chris Hemsworth  Robert Downey Jr.
# 47  3.630243e-108      Ryan Reynolds          Ed Skrein
# 32  4.246456e-108  Jennifer Lawrence    Josh Hutcherson
# 12  4.149845e-108          Tom Hanks  John Ratzenberger
#
#              actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  \
# 97                      0                     131                    12.0
# ...

# %%
# Creating new column "Profit" 
movies["Profit"] = movies["Gross"] - movies["budget"]
movies
# Out:
#                                          Title  title_year        budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015  2.450000e-83
# 11                                The Avengers        2012  2.200000e-83
# 47                                    Deadpool        2016  5.800000e-84
# 32             The Hunger Games: Catching Fire        2013  1.300000e-83
# 12                                 Toy Story 3        2010  2.000000e-83
# ..                                         ...         ...           ...
# 46                 Scott Pilgrim vs. the World        2010  6.000000e-84
# 7                                      Tangled        2010  2.600000e-83
# 17                            Edge of Tomorrow        2014  1.780000e-83
# 39                           The Little Prince        2015  8.120000e-84
# 22                                        Hugo        2011  1.700000e-83
#
#            Gross         actor_1_name       actor_2_name  \
# ...

# %%
# # Sort the dataframe with the 'profit' column as reference using the 'sort_values' function. Make sure to set the argument
#'ascending' to 'False'
movies = movies.sort_values(by="Profit", ascending=False)

# %%
# Get the top 10 profitable movies by using position based indexing. Specify the rows till 10 (0-9)
movies.iloc[:10]
# Out:
#                                          Title  title_year        budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015  2.450000e-52
# 11                                The Avengers        2012  2.200000e-52
# 47                                    Deadpool        2016  5.800000e-53
# 32             The Hunger Games: Catching Fire        2013  1.300000e-52
# 12                                 Toy Story 3        2010  2.000000e-52
# 8                        The Dark Knight Rises        2012  2.500000e-52
# 45                              The Lego Movie        2014  6.000000e-53
# 1                                     Zootopia        2016  1.500000e-52
# 41                               Despicable Me        2010  6.900000e-53
# 18                                  Inside Out        2015  1.750000e-52
#
#            Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  9.366622e-52        Doug Walker         Rob Walker                      0
# ...

# %%
# Ploting Profit vs budget
sns.jointplot("budget","Profit",movies)
plt.show()

# %%
# Movies with Negative profit
movies[movies["Profit"]<0]
# Out:
#                           Title  title_year         budget          Gross  \
# 99      Tucker and Dale vs Evil        2010  5.000000e-110  2.238380e-111
# 89                        Amour        2012  8.900000e-110  2.253770e-111
# 56                         Rush        2013  3.800000e-109  2.690371e-109
# 66                      Warrior        2011  2.500000e-109  1.365166e-109
# 82                      Flipped        2010  1.400000e-109  1.752214e-110
# 28           X-Men: First Class        2011  1.600000e-108  1.464054e-108
# 46  Scott Pilgrim vs. the World        2010  6.000000e-109  3.149427e-109
# 7                       Tangled        2010  2.600000e-108  2.008073e-108
# 17             Edge of Tomorrow        2014  1.780000e-108  1.001895e-108
# 39            The Little Prince        2015  8.120000e-109  1.339152e-110
# 22                         Hugo        2011  1.700000e-108  7.382009e-109
#
#            actor_1_name        actor_2_name            actor_3_name  \
# ...

# %%
# changing the scale of Metacritic
movies["MetaCritic"] = movies["MetaCritic"]/10

# %%
# Average Ratings of Movies
movies["Avg_rating"] = (movies["IMDb_rating"] + movies["MetaCritic"]) / 2

# %%
movies
# Out:
#                                 Title  title_year         budget  \
# 27                          Inception        2010  1.600000e-108
# 95                           Whiplash        2014  3.300000e-110
# 26                       Interstellar        2014  1.650000e-108
# 12                        Toy Story 3        2010  2.000000e-108
# 35                   Django Unchained        2012  1.000000e-108
# ..                                ...         ...            ...
# 16  The Hobbit: An Unexpected Journey        2012  1.800000e-108
# 52                      Lone Survivor        2013  4.000000e-109
# 88                         About Time        2013  1.200000e-109
# 71                     The Book Thief        2013  1.900000e-109
# 82                            Flipped        2010  1.400000e-109
#
#             Gross         actor_1_name       actor_2_name  \
# 27  2.925689e-108    Leonardo DiCaprio          Tom Hardy
# 95  1.309200e-109         J.K. Simmons    Melissa Benoist
# ...

# %%
# sorting average rating in descending order
df=movies[["Title","IMDb_rating","MetaCritic","Avg_rating"]]
df = df.loc[abs(df["IMDb_rating"] - df["MetaCritic"] < 0.5)]

# %%
# Find the movies with metacritic-IMDb_rating < 0.5 and also with the average rating of >8
df=df.sort_values(by="Avg_rating",ascending=False)
UniversalAcclaim=df.loc[df["Avg_rating"]>=8]
UniversalAcclaim
# Out:
# Empty DataFrame
# Columns: [Title, IMDb_rating, MetaCritic, Avg_rating]
# Index: []

# %%
# Grouping the actor names with high facebook likes
group = movies.pivot_table(values=["actor_1_facebook_likes","actor_2_facebook_likes","actor_3_facebook_likes"],
        aggfunc = "sum", index = ["actor_1_name","actor_2_name","actor_3_name"])
group
# Out:
#                                                     actor_1_facebook_likes  \
# actor_1_name  actor_2_name    actor_3_name
# Aidan Turner  Adam Brown      James Nesbitt                          10000
# Albert Finney Helen McCrory   Rory Kinnear                             883
# Aldis Hodge   Neil Brown Jr.  R. Marcos Taylor                         559
# Amy Adams     Jeremy Renner   Forest Whitaker                        35000
# Amy Poehler   Mindy Kaling    Phyllis Smith                           1000
# ...                                                                    ...
# Tom Hanks     Mark Rylance    Amy Ryan                               15000
# Tom Hardy     Charlize Theron ZoÃ« Kravitz                           27000
#               Christian Bale  Joseph Gordon-Levitt                   27000
#               Frank Grillo    Kevin Dunn                             27000
# Tom Hughes    Tom Hollander   Lindsay Duncan                           565
#
# ...

# %%
# Total likes
group["Total likes"] = group["actor_1_facebook_likes"] + group["actor_2_facebook_likes"] + group["actor_3_facebook_likes"]
group
# Out:
#                                                     actor_1_facebook_likes  \
# actor_1_name  actor_2_name    actor_3_name
# Aidan Turner  Adam Brown      James Nesbitt                          10000
# Albert Finney Helen McCrory   Rory Kinnear                             883
# Aldis Hodge   Neil Brown Jr.  R. Marcos Taylor                         559
# Amy Adams     Jeremy Renner   Forest Whitaker                        35000
# Amy Poehler   Mindy Kaling    Phyllis Smith                           1000
# ...                                                                    ...
# Tom Hanks     Mark Rylance    Amy Ryan                               15000
# Tom Hardy     Charlize Theron ZoÃ« Kravitz                           27000
#               Christian Bale  Joseph Gordon-Levitt                   27000
#               Frank Grillo    Kevin Dunn                             27000
# Tom Hughes    Tom Hollander   Lindsay Duncan                           565
#
# ...

# %%
# sorting the total likes in descending
group.sort_values(by="Total likes", ascending=False, inplace = True)
group
# Out:
#                                                                     actor_1_facebook_likes  \
# actor_1_name             actor_2_name       actor_3_name
# Dev Patel                Nicole Kidman      Rooney Mara                              33000
# Leonardo DiCaprio        Tom Hardy          Joseph Gordon-Levitt                     29000
# Jennifer Lawrence        Peter Dinklage     Hugh Jackman                             34000
# Casey Affleck            Michelle Williams  Kyle Chandler                              518
# Tom Hardy                Christian Bale     Joseph Gordon-Levitt                     27000
# ...                                                                                    ...
# Ellar Coltrane           Lorelei Linklater  Libby Villari                              230
# Elina Alminas            Sonoya Mizuno      Corey Johnson                              149
# Seamus Davey-Fitzpatrick Ariane Labed       Athina Rachel Tsangari                     140
# ...

# %%
group.reset_index(inplace=True)
group
# Out:
#     index              actor_1_name        actor_2_name  \
# 0       0                 Dev Patel       Nicole Kidman
# 1       1         Leonardo DiCaprio           Tom Hardy
# 2       2         Jennifer Lawrence      Peter Dinklage
# 3       3             Casey Affleck  Michelle Williams
# 4       4                 Tom Hardy      Christian Bale
# ..    ...                       ...                 ...
# 94     94            Ellar Coltrane   Lorelei Linklater
# 95     95             Elina Alminas       Sonoya Mizuno
# 96     96  Seamus Davey-Fitzpatrick        Ariane Labed
# 97     97               Doug Walker          Rob Walker
# 98     98            Phaldut Sharma       Basher Savage
#
#               actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  \
# 0              Rooney Mara                   33000                 96000.0
# 1     Joseph Gordon-Levitt                   29000                 27000.0
# ...

# %%
group = group.iloc[0:5,:]
group
# Out:
#    index       actor_1_name        actor_2_name          actor_3_name  \
# 0      0          Dev Patel       Nicole Kidman           Rooney Mara
# 1      1  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 2      2  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 3      3      Casey Affleck  Michelle Williams          Kyle Chandler
# 4      4          Tom Hardy      Christian Bale  Joseph Gordon-Levitt
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                   33000                 96000.0                  9800.0
# 1                   29000                 27000.0                 23000.0
# 2                   34000                 22000.0                 20000.0
# 3                     518                 71000.0                  3300.0
# 4                   27000                 23000.0                 23000.0
#
#    Total likes
# 0     138800.0
# 1      79000.0
# 2      76000.0
# 3      74818.0
# 4      73000.0

# %%
# popular Trios
j=0
for i in group["Total likes"]:
    temp=sorted([group.loc[j,"actor_1_facebook_likes"],group.loc[j,"actor_2_facebook_likes"],group.loc[j,"actor_3_facebook_likes"]])
    if temp[0]>= temp[1]/2 and temp[0]>=temp[2]/2 and temp[1]>=temp[2]/2:
        print(sorted([group.loc[j,"actor_1_name"],group.loc[j,"actor_2_name"],group.loc[j,"actor_3_name"]]))

    j=j+1
# Out:
# ['Joseph Gordon-Levitt', 'Leonardo DiCaprio', 'Tom Hardy']
# ['Hugh Jackman', 'Jennifer Lawrence', 'Peter Dinklage']
# ['Christian Bale', 'Joseph Gordon-Levitt', 'Tom Hardy']

# %%
# Runtime histogram/density plot
plt.hist(movies["Runtime"])
plt.show()

# %%
# Movies Rated R
movies.loc[movies["content_rating"]=="R"].sort_values(by="CVotesU18",ascending=False)[["Title","CVotesU18"]].head(10)
# Out:
#                                               Title  CVotesU18
# 47                                         Deadpool       4598
# 36                          The Wolf of Wall Street       3622
# 35                                 Django Unchained       3250
# 29                               Mad Max: Fury Road       3159
# 95                                         Whiplash       2878
# 31                                     The Revenant       2619
# 40                                   Shutter Island       2321
# 43                                        Gone Girl       2286
# 65                         The Grand Budapest Hotel       2083
# 72  Birdman or (The Unexpected Virtue of Ignorance)       1891

# %%
# Create the dataframe df_by_genre

df_by_genre=movies.loc[:,"CVotes10":"VotesnUS"]
df_by_genre[["genre_1","genre_2","genre_3"]]=movies[["genre_1","genre_2","genre_3"]]
df_by_genre
# Out:
#     CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  CVotes04  \
# 27    584839    485218    304457    130972     46393     20595     10050
# 95    110404    161864    132656     56007     16577      6031      2937
# 26    394006    291172    199884    103323     40514     17423      8657
# 12    139773    149992    158704     88289     31291     11850      4859
# 35    234824    339329    286911    121445     38251     14227      6469
# ..       ...       ...       ...       ...       ...       ...       ...
# 16    135848    132202    191128    122538     51765     19699      8227
# 52     30856     33356     68808     54195     20772      7205      2727
# 88     38556     43170     70850     45487     16542      5673      2210
# 71     15911     17607     32570     24461     10274      3848      1387
# 82     11354     11050     20808     14372      5412      1848       664
#
#     CVotes03  CVotes02  CVotes01  ...  Votes3044F  Votes45A  Votes45AM  \
# ...

# %%
# creating a column adn assign 1 to it
df_by_genre["cnt"]=1

# %%
df_by_genre[["genre_1","genre_2","genre_3"]]
# Out:
#       genre_1    genre_2  genre_3
# 27     Action  Adventure   Sci-Fi
# 95      Drama      Music      NaN
# 26  Adventure      Drama   Sci-Fi
# 12  Animation  Adventure   Comedy
# 35      Drama    Western      NaN
# ..        ...        ...      ...
# 16  Adventure    Fantasy      NaN
# 52     Action  Biography    Drama
# 88     Comedy      Drama  Fantasy
# 71      Drama        War      NaN
# 82     Comedy      Drama  Romance
#
# [100 rows x 3 columns]

# %%
# Grouping the movies by genre
df_by_g1=df_by_genre.groupby("genre_1").aggregate(np.sum)
df_by_g2=df_by_genre.groupby("genre_2").aggregate(np.sum)
df_by_g3=df_by_genre.groupby("genre_3").aggregate(np.sum)

# %%
# Dataframe of Genre 1
df_by_g1
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_1
# Action      2928407   3261919   4247693   2662020    986774    364234
# Adventure   1058779   1179818   1560541    966275    365486    136985
# Animation    681562    798227   1153214    722782    251076     83069
# Biography    666831   1088430   1654704    962977    306247    100005
# Comedy       371217    496905    770395    518566    205434     81933
# Crime        383290    690221   1083469    627593    206756     71460
# Drama       1080725   1494053   1827363   1078966    417205    163874
# Mystery      150405    230844    278844    132349     45167     15615
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# genre_1                                            ...
# Action       156150     89483     61975    162426  ...      209.1       208.8
# Adventure     58559     33174     22018     48100  ...       92.7        92.6
# ...

# %%
# Dataframe of Genre 2
df_by_g2
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_2
# Action       238060    285510    430062    260106     88580     29250
# Adventure   2297820   2548864   3271725   2055600    758009    272735
# Biography    185172    313178    576374    370003    119348     38643
# Comedy       428995    624720    854162    512668    193916     76752
# Crime         19576     40247     85359     64633     24920      8548
# Drama       1923492   2761237   4112363   2492241    853434    300100
# Family        68937     54947    102488     80465     31205     11792
# Fantasy      270616    290831    447307    291071    120920     47215
# History       15757     32840     83322     63800     19183      5178
# Horror        16572     19818     44460     35863     13456      4588
# Music        110404    161864    132656     56007     16577      6031
# Musical       54268     47750     63323     45160     22393     10744
# ...

# %%
# Dataframe of Genre 3
df_by_g3
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_3
# Adventure    238060    285510    430062    260106     88580     29250
# Comedy       583404    653362    882294    559835    200937     68167
# Crime        171660    236650    250667    129164     46715     18682
# Drama        400221    680085   1167327    748493    258717     88338
# Family        29228     40728     77893     62936     27932     11179
# Fantasy      301836    311392    442460    308676    120911     46269
# History      135504    227547    311209    159262     48678     16055
# Music         74245     71191     64640     38831     17377      8044
# Mystery      274446    443661    654167    375087    128131     44818
# Romance      319534    418790    715954    497486    193588     75675
# Sci-Fi      1975041   2169036   2569011   1517219    546668    200825
# Sport         95717    140282    214806    138600     44470     13821
# ...

# %%
# Adding the grouped data frames and store it in a new data frame
df_add = df_by_g1.add(df_by_g2, fill_value=0)
df_add = df_add.add(df_by_g3, fill_value=0)
df_add
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Family       98165.0    95675.0   180381.0   143401.0    59137.0   22971.0
# Fantasy     572452.0   602223.0   889767.0   599747.0   241831.0   93484.0
# History     151261.0   260387.0   394531.0   223062.0    67861.0   21233.0
# Horror       16572.0    19818.0    44460.0    35863.0    13456.0    4588.0
# ...

# %%
# Extracting genres with atleast 10 occurences
genre_top_10 =  df_add.loc[df_add["cnt"]>10]
genre_top_10
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Romance     549959.0   689492.0  1069280.0   712841.0   281289.0  110901.0
# Sci-Fi     2325284.0  2530855.0  3002994.0  1802098.0   671811.0  254175.0
# Thriller   1081701.0  1465491.0  1993378.0  1175799.0   416046.0  149953.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# ...

# %%
# Rounding off the columns of Votes to two decimals
genre_top_10.loc[:,"VotesM":"VotesnUS"]=round(genre_top_10.loc[:,"VotesM":"VotesnUS"],2)

# %%
# Converting CVotes to int type
genre_top_10[genre_top_10.loc[:,"CVotes10":"CVotesnUS"].columns]=genre_top_10[genre_top_10.loc[:,"CVotes10":"CVotesnUS"].columns].astype(int)
genre_top_10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action      3166467   3547429   4677755   2922126   1075354    393484
# Adventure   3594659   4014192   5262328   3281981   1212075    438970
# Animation    681562    798227   1153214    722782    251076     83069
# Biography    852003   1401608   2231078   1332980    425595    138648
# Comedy      1383616   1774987   2506851   1591069    600287    226852
# Crime        574526    967118   1419495    821390    278391     98690
# Drama       3404438   4935375   7107053   4319700   1529356    552312
# Romance      549959    689492   1069280    712841    281289    110901
# Sci-Fi      2325284   2530855   3002994   1802098    671811    254175
# Thriller    1081701   1465491   1993378   1175799    416046    149953
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# Action       166970     95004     65573    171247  ...      240.0       239.5
# ...

# %%
# Counting plot of Genres
sns.barplot(x=genre_top_10["cnt"],y=genre_top_10.index)
plt.show()

# %%
# 1st Heat maps for CVotes-related columns
plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
ax=sns.heatmap(genre_top_10[["CVotesU18M","CVotes1829M","CVotes3044M","CVotes45AM"]],annot=True,cmap="coolwarm")

plt.subplot(1,2,2)
ax=sns.heatmap(genre_top_10[["CVotesU18F","CVotes1829F","CVotes3044F","CVotes45AF"]],annot=True,cmap="coolwarm")

plt.show()

# %%
# 2nd Heat maps for Votes-related columns
plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
ax=sns.heatmap(genre_top_10[["VotesU18M","Votes1829M","Votes3044M","CVotes45AM"]],annot=True,cmap="coolwarm")

plt.subplot(1,2,2)
ax=sns.heatmap(genre_top_10[["CVotesU18F","CVotes1829F","CVotes3044F","CVotes45AF"]],annot=True,cmap="coolwarm")

plt.show()

# %%
# Country list
movies["Country"].value_counts()
# Out:
# USA          81
# UK           11
# France        3
# Australia     3
# Canada        1
# Spain         1
# Name: Country, dtype: int64

# %%
# IF US Movies column
movies["IFUS"] = movies["Country"].copy()
movies.loc[movies["IFUS"] != "USA", "IFUS"] = "non-USA"

# %%
# Num of US and Non-US Countries
movies["IFUS"].value_counts()
# Out:
# USA        81
# non-USA    19
# Name: IFUS, dtype: int64

# %%
# Box-Plot 1 X=IFUS Y=CVoteUS
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.boxplot(x="IFUS", y="CVotesUS", data=movies)

plt.subplot(1,2,2)
sns.boxplot(x="IFUS", y="CVotesnUS", data=movies)

plt.show()

# %% [markdown]
# Inference 1: US Movies has got higher votings from both US and Non-US audiences.
# Inference 2: Non-US movies has got uniform distribution of Voting by both US and Non-US audiences.

# %%
# Box-Plot 2 IFUS(x) VoteUS(y)
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.boxplot(x="IFUS", y="VotesUS", data=movies)

plt.subplot(1,2,2)
sns.boxplot(x="IFUS", y="VotesnUS", data=movies)

plt.show()

# %% [markdown]
# Inference 1: US movies has got higher votings from US audience than non-US voters, which is evident from median.
# Inference 2: Some US movies got exceptionnexceptionally high rating from US audiences. While,there are no such extreme rating for the any of the Non-US movies.

# %%
# Sorting CVotes1000
genre_top_10 = genre_top_10.sort_values(by="CVotes1000", ascending =False)
genre_top_10["CVotes1000"]
# Out:
# Drama        38086
# Adventure    25157
# Action       21123
# Comedy       13934
# Sci-Fi       12146
# Biography    10804
# Thriller      8705
# Romance       7130
# Crime         6821
# Animation     6364
# Name: CVotes1000, dtype: int32

# %%
# Bar Plot
plt.figure(figsize=(12,5))
sns.barplot(genre_top_10.index, genre_top_10["CVotes1000"])
plt.show()

# %% [markdown]
# Inference 1: Drama has the highest rating when compairng to all the other genres
# Inference 2:
